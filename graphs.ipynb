# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
df3 = pd.read_csv('/Users/ianforrest/Downloads/novel-corona-virus-2019-dataset/time_series_covid_19_confirmed.csv')
df3 = df3[['Country/Region', 'Province/State','Lat', 'Long','3/19/20']]
df3 = df3.rename(columns={"3/19/20": "3_19_20_c"})
df3['3_19_20_d'] = df4['3_19_20_d']
df3['3_19_20_r'] = df5['3_19_20_r']
df3.head()
# Out:
#   Country/Region Province/State      Lat      Long  3_19_20_c  3_19_20_d  \
# 0       Thailand            NaN  15.0000  101.0000        272          1
# 1          Japan            NaN  36.0000  138.0000        924         29
# 2      Singapore            NaN   1.2833  103.8333        345          0
# 3          Nepal            NaN  28.1667   84.2500          1          0
# 4       Malaysia            NaN   2.5000  112.5000        900          2
#
#    3_19_20_r
# 0         42
# 1        150
# 2        114
# 3          1
# 4         75

# %%
# Extract the data we're interested in
lat = df3['Lat'].values
lon = df3['Long'].values
con = df3['3_19_20_c'].values
dead = df3['3_19_20_d'].values
rec = df3['3_19_20_r'].values

# %%
# 1. Draw the map background
fig = plt.figure(figsize=(8, 8))
m = Basemap()
m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')
# 2. scatter city data, with color reflecting population
# and size reflecting area
m.scatter(lon, lat, latlon=True, s = dead, alpha=0.5, cmap='Reds')
plt.show()

# %%
df4 = pd.read_csv('/Users/ianforrest/Downloads/novel-corona-virus-2019-dataset/time_series_covid_19_deaths.csv')
df4 = df4[['Country/Region', 'Province/State','Lat', 'Long','3/19/20']]
df4 = df4.rename(columns={"3/19/20": "3_19_20_d"})
df4.head()
# Out:
#   Country/Region Province/State      Lat      Long  3_19_20_d
# 0       Thailand            NaN  15.0000  101.0000          1
# 1          Japan            NaN  36.0000  138.0000         29
# 2      Singapore            NaN   1.2833  103.8333          0
# 3          Nepal            NaN  28.1667   84.2500          0
# 4       Malaysia            NaN   2.5000  112.5000          2

# %%
df5 = pd.read_csv('/Users/ianforrest/Downloads/novel-corona-virus-2019-dataset/time_series_covid_19_recovered.csv')
df5 = df5[['Country/Region', 'Province/State','Lat', 'Long','3/19/20']]
df5 = df5.rename(columns={"3/19/20": "3_19_20_r"})
df5.head()
# Out:
#   Country/Region Province/State      Lat      Long  3_19_20_r
# 0       Thailand            NaN  15.0000  101.0000         42
# 1          Japan            NaN  36.0000  138.0000        150
# 2      Singapore            NaN   1.2833  103.8333        114
# 3          Nepal            NaN  28.1667   84.2500          1
# 4       Malaysia            NaN   2.5000  112.5000         75
